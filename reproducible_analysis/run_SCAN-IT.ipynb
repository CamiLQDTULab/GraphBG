# %%
pip install scanpy
# Out:
# Requirement already satisfied: scanpy in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (1.9.6)
# Requirement already satisfied: anndata>=0.7.4 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (0.10.9)
# Requirement already satisfied: get-annotations in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (0.1.2)
# Requirement already satisfied: h5py>=3 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (3.13.0)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (1.4.2)
# Requirement already satisfied: matplotlib>=3.4 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (3.9.2)
# Requirement already satisfied: natsort in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (7.1.1)
# Requirement already satisfied: networkx>=2.3 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (2.8.8)
# Requirement already satisfied: numba>=0.41.0 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=1.17.0 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (1.26.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (25.0)
# Requirement already satisfied: pandas!=2.1.2,>=1.1.1 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (2.2.3)
# Requirement already satisfied: patsy in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.24 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (1.6.1)
# Requirement already satisfied: scipy>=1.4 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (1.13.1)
# Requirement already satisfied: seaborn!=0.13.0 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (1.0.0)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (0.14.4)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (4.67.1)
# Requirement already satisfied: umap-learn>=0.3.10 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scanpy) (0.5.7)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from anndata>=0.7.4->scanpy) (1.11.2)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from anndata>=0.7.4->scanpy) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from matplotlib>=3.4->scanpy) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.4->scanpy) (3.23.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from numba>=0.41.0->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from pandas!=2.1.2,>=1.1.1->scanpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from pandas!=2.1.2,>=1.1.1->scanpy) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.4->scanpy) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from scikit-learn>=0.24->scanpy) (3.5.0)
# Requirement already satisfied: pynndescent>=0.5 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from umap-learn>=0.3.10->scanpy) (0.5.4)
# Requirement already satisfied: stdlib-list in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from session-info->scanpy) (0.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gudhi
# Out:
# Requirement already satisfied: gudhi in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (3.11.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/envs/scanit_env/lib/python3.9/site-packages (from gudhi) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gc
import scanit
import torch
import torch
import random
import scanpy as sc
import pandas as pd
import anndata
import numpy as np
from scipy import sparse
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score
from sklearn.cluster import SpectralClustering, KMeans
import matplotlib.pyplot as plt
# import stlearn as st
from pathlib import Path

# %%
adata = sc.read('/Users/melancholy/Desktop/Maynard dataset/151510.h5ad')
adata.obs['Region']
# Out:
# AAACAAGTATCTCCCA-1    Layer1
# AAACACCAATAACTGC-1    Layer5
# AAACAGAGCGACTCCT-1    Layer3
# AAACAGCTTTCAGAAG-1    Layer4
# AAACAGGGTCTATATT-1    Layer4
#                        ...
# TTGTTTCACATCCAGG-1    Layer4
# TTGTTTCATTAGTCTA-1    Layer5
# TTGTTTCCATACAACT-1    Layer3
# TTGTTTGTATTACACG-1    Layer6
# TTGTTTGTGTAAATTC-1    Layer3
# Name: Region, Length: 4634, dtype: category
# Categories (7, object): ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'WM']

# %%
import scanpy as sc
import pandas as pd
import numpy as np
from sklearn.metrics import normalized_mutual_info_score, homogeneity_score, completeness_score
import scanit
import os

# Cài đặt đường dẫn
datadir = '/Users/melancholy/Desktop/Maynard dataset'
result_path = '/Users/melancholy/Desktop'

# Danh sách tên file (12 file)
sample_ids = ['151507', '151508', '151509', '151510'] + [str(sid) for sid in range(151669, 151677)]

# Hàm tìm resolution phù hợp với số cụm mong muốn
def res_search_fixed_clus(adata, fixed_clus_count, increment=0.02):
    for res in sorted(list(np.arange(0.15, 5, increment)), reverse=True):
        sc.tl.leiden(adata, random_state=0, resolution=res)
        count_unique_leiden = len(adata.obs['leiden'].unique())
        if count_unique_leiden == fixed_clus_count:
            break
    return res

# Danh sách lưu kết quả
metrics_list = []

# Vòng lặp qua từng file
for i, sid in enumerate(sample_ids):
    file_path = os.path.join(datadir, f'{sid}.h5ad')
    print(f'\n--- Processing file: {sid}.h5ad ---')

    # Đọc dữ liệu
    adata = sc.read_h5ad(file_path)
    new_data = adata.copy()
    adata_sp = adata.copy()

    # Tiền xử lý
    sc.pp.normalize_total(adata_sp)
    sc.pp.log1p(adata_sp)
    sc.pp.scale(adata_sp)

    # SCAN-IT embedding
    scanit.tl.spatial_graph(adata_sp, method='alpha shape', alpha_n_layer=2, knn_n_neighbors=5)
    scanit.tl.spatial_representation(
        adata_sp, 
        n_h=30, n_epoch=2000, lr=0.001, device='cpu', 
        n_consensus=1, projection='mds', 
        python_seed=0, torch_seed=0, numpy_seed=0
    )

    # Gán số cụm mong muốn
    if sid in ['151669', '151670', '151671', '151672']:
        n_clusters = 5
    else:
        n_clusters = 7

    # Clustering
    sc.pp.neighbors(adata_sp, use_rep='X_scanit', n_neighbors=15)
    eval_resolution = res_search_fixed_clus(adata_sp, n_clusters)
    sc.tl.leiden(adata_sp, key_added="scanit_leiden", resolution=eval_resolution)

    # Tính NMI, HOM, COM
    obs_df = adata_sp.obs.dropna()
    if 'Region' not in obs_df.columns:
        print(f"⚠️  File {sid}.h5ad thiếu nhãn 'Region'. Bỏ qua.")
        continue

    labels_true = obs_df['Region']
    labels_pred = obs_df['scanit_leiden']

    nmi = normalized_mutual_info_score(labels_true, labels_pred)
    hom = homogeneity_score(labels_true, labels_pred)
    com = completeness_score(labels_true, labels_pred)

    metrics_list.append({
        'File': f'{sid}.h5ad',
        'NMI': nmi,
        'HOM': hom,
        'COM': com
    })

    # Gán nhãn vào bản sao new_data và lưu
    new_data.obs[f'pred_{i+1}'] = adata_sp.obs['scanit_leiden']
    new_data.uns['nmi'] = nmi
    new_data.uns['hom'] = hom
    new_data.uns['com'] = com

    out_path = os.path.join(result_path, f'SCAN-IT_{sid}.h5ad')
    new_data.write(out_path)
    print(f"✅ Done: {sid}.h5ad | NMI = {nmi:.4f}, HOM = {hom:.4f}, COM = {com:.4f} | Saved to: {out_path}")

# In danh sách NMI/HOM/COM và lưu vào CSV
df_metrics = pd.DataFrame(metrics_list)
print("\n=== Tổng hợp chỉ số NMI / HOM / COM ===")
print(df_metrics)

csv_out = os.path.join(result_path, 'NMI_summary.csv')
df_metrics.to_csv(csv_out, index=False)
print(f"\n📄 Đã lưu NMI tổng hợp vào: {csv_out}")
# Out:
# --- Processing file: 151507.h5ad ---
# Epoch: 000, Loss: 1.3982
# Epoch: 500, Loss: 0.0009
# Epoch: 1000, Loss: 0.0004
# Epoch: 1500, Loss: 0.0001
# Epoch: 1999, Loss: 0.0000
# ✅ Done: 151507.h5ad | NMI = 0.6379, HOM = 0.5916, COM = 0.6919 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151507.h5ad
#
# --- Processing file: 151508.h5ad ---
# Epoch: 000, Loss: 1.4016
# Epoch: 500, Loss: 0.0005
# Epoch: 1000, Loss: 0.0001
# Epoch: 1500, Loss: 0.0000
# Epoch: 1999, Loss: 0.0000
# ✅ Done: 151508.h5ad | NMI = 0.5564, HOM = 0.5727, COM = 0.5410 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151508.h5ad
#
# --- Processing file: 151509.h5ad ---
# Epoch: 000, Loss: 1.4059
# Epoch: 500, Loss: 0.0006
# Epoch: 1000, Loss: 0.0000
# Epoch: 1500, Loss: 0.0003
# Epoch: 1999, Loss: 0.0001
# ✅ Done: 151509.h5ad | NMI = 0.6498, HOM = 0.6936, COM = 0.6111 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151509.h5ad
#
# --- Processing file: 151510.h5ad ---
# Epoch: 000, Loss: 1.4030
# Epoch: 500, Loss: 0.0004
# Epoch: 1000, Loss: 0.0002
# Epoch: 1500, Loss: 0.0002
# Epoch: 1999, Loss: 0.0000
# ✅ Done: 151510.h5ad | NMI = 0.5569, HOM = 0.5932, COM = 0.5248 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151510.h5ad
#
# --- Processing file: 151669.h5ad ---
# Epoch: 000, Loss: 1.3988
# Epoch: 500, Loss: 0.0009
# Epoch: 1000, Loss: 0.0000
# Epoch: 1500, Loss: 0.0001
# Epoch: 1999, Loss: 0.0000
# ✅ Done: 151669.h5ad | NMI = 0.4760, HOM = 0.5627, COM = 0.4124 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151669.h5ad
#
# --- Processing file: 151670.h5ad ---
# Epoch: 000, Loss: 1.4009
# Epoch: 500, Loss: 0.0013
# Epoch: 1000, Loss: 0.0001
# Epoch: 1500, Loss: 0.0108
# Epoch: 1999, Loss: 0.0099
# ✅ Done: 151670.h5ad | NMI = 0.4283, HOM = 0.5710, COM = 0.3427 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151670.h5ad
#
# --- Processing file: 151671.h5ad ---
# Epoch: 000, Loss: 1.4057
# Epoch: 500, Loss: 0.0063
# Epoch: 1000, Loss: 0.0002
# Epoch: 1500, Loss: 0.0000
# Epoch: 1999, Loss: 0.0000
# ✅ Done: 151671.h5ad | NMI = 0.5879, HOM = 0.7153, COM = 0.4990 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151671.h5ad
#
# --- Processing file: 151672.h5ad ---
# Epoch: 000, Loss: 1.4016
# Epoch: 500, Loss: 0.0050
# Epoch: 1000, Loss: 0.0004
# Epoch: 1500, Loss: 0.0001
# Epoch: 1999, Loss: 0.0000
# ✅ Done: 151672.h5ad | NMI = 0.6410, HOM = 0.7243, COM = 0.5749 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151672.h5ad
#
# --- Processing file: 151673.h5ad ---
# Epoch: 000, Loss: 1.4121
# Epoch: 500, Loss: 0.0036
# Epoch: 1000, Loss: 0.0011
# Epoch: 1500, Loss: 0.0004
# Epoch: 1999, Loss: 0.0001
# ✅ Done: 151673.h5ad | NMI = 0.5211, HOM = 0.5100, COM = 0.5328 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151673.h5ad
#
# --- Processing file: 151674.h5ad ---
# Epoch: 000, Loss: 1.4149
# Epoch: 500, Loss: 0.0013
# Epoch: 1000, Loss: 0.0001
# Epoch: 1500, Loss: 0.0002
# Epoch: 1999, Loss: 0.0023
# ✅ Done: 151674.h5ad | NMI = 0.5652, HOM = 0.5915, COM = 0.5412 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151674.h5ad
#
# --- Processing file: 151675.h5ad ---
# Epoch: 000, Loss: 1.4090
# Epoch: 500, Loss: 0.0004
# Epoch: 1000, Loss: 0.0060
# Epoch: 1500, Loss: 0.0001
# Epoch: 1999, Loss: 0.0001
# ✅ Done: 151675.h5ad | NMI = 0.5496, HOM = 0.5503, COM = 0.5489 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151675.h5ad
#
# --- Processing file: 151676.h5ad ---
# Epoch: 000, Loss: 1.4062
# Epoch: 500, Loss: 0.0004
# Epoch: 1000, Loss: 0.0001
# Epoch: 1500, Loss: 0.0100
# Epoch: 1999, Loss: 0.0115
# ✅ Done: 151676.h5ad | NMI = 0.4687, HOM = 0.4850, COM = 0.4535 | Saved to: /Users/melancholy/Desktop/SCAN-IT_151676.h5ad
#
# === Tổng hợp chỉ số NMI / HOM / COM ===
#            File       NMI       HOM       COM
# 0   151507.h5ad  0.637850  0.591598  0.691949
# 1   151508.h5ad  0.556421  0.572735  0.541010
# 2   151509.h5ad  0.649763  0.693606  0.611133
# 3   151510.h5ad  0.556927  0.593216  0.524821
# 4   151669.h5ad  0.475954  0.562679  0.412392
# 5   151670.h5ad  0.428343  0.571045  0.342702
# 6   151671.h5ad  0.587870  0.715268  0.498993
# 7   151672.h5ad  0.641018  0.724257  0.574941
# 8   151673.h5ad  0.521138  0.509963  0.532814
# 9   151674.h5ad  0.565233  0.591542  0.541165
# 10  151675.h5ad  0.549594  0.550267  0.548922
# 11  151676.h5ad  0.468737  0.484980  0.453547
#
# 📄 Đã lưu NMI tổng hợp vào: /Users/melancholy/Desktop/NMI_summary.csv

# %%
import pandas as pd

# Đọc file gốc
df_others = pd.read_csv("/Users/melancholy/Desktop/results section b and c/result_metrics_10xVisium.csv")

# Đọc file SCAN-IT
df_scanit = pd.read_csv("/Users/melancholy/Desktop/metric_summary.csv")

# Đổi tên cột cho giống df_others
df_scanit = df_scanit.rename(columns={"File": "DataName"})

# Xóa phần .h5ad khỏi DataName
df_scanit["DataName"] = df_scanit["DataName"].str.replace(".h5ad", "", regex=False)

# Thêm cột Method = "SCAN-IT"
df_scanit["Method"] = "SCAN-IT"

# Gộp 2 dataframe
df_concat = pd.concat([df_others, df_scanit], ignore_index=True)

# Sắp xếp lại cột đúng thứ tự nếu cần
df_concat = df_concat[["DataName", "Method", "NMI", "HOM", "COM"]]

# Lưu ra file mới
df_concat.to_csv("/Users/melancholy/Desktop/metrics_all_methods.csv", index=False)
df_concat
# Out:
#     DataName   Method       NMI       HOM       COM
# 0     151669  GraphBG  0.675974  0.740235  0.621979
# 1     151669  GraphST  0.649642  0.609027  0.696061
# 2     151508  GraphBG  0.637682  0.637907  0.637457
# 3     151508  GraphST  0.643654  0.644672  0.642640
# 4     151509  GraphBG  0.691697  0.714134  0.670628
# ..       ...      ...       ...       ...       ...
# 391   151672  SCAN-IT  0.641018  0.724257  0.574941
# 392   151673  SCAN-IT  0.521138  0.509963  0.532814
# 393   151674  SCAN-IT  0.565233  0.591542  0.541165
# 394   151675  SCAN-IT  0.549594  0.550267  0.548922
# 395   151676  SCAN-IT  0.468737  0.484980  0.453547
#
# [396 rows x 5 columns]
